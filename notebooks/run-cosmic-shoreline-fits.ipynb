# %% [markdown]
# # Run Cosmic Shoreline Fits + Plots
#
# This little wrapper notebook runs all the notebooks needed to recalculate new cosmic shoreline fits and make plots from them. It might jam up a few times and need to be restarted. Let's start by making some directories to populate with results.

# %%
# !mkdir figures
# !mkdir paper-figures

# %% [markdown]
# Let's list the notebooks we want to run. Ones starting with `x-` don't need to run.

# %%
# !ls *.ipynb

# %% [markdown]
# Let's run the notebooks in order.

# %%
from IPython import get_ipython
from shoreline import * 

for f in '''1-fit-mass-radius-relation.ipynb
    2-curate-and-label-planets.ipynb
    3-fit-one-shoreline.ipynb
    4-fit-many-shorelines.ipynb
    5-print-and-visualize-posteriors.ipynb
    6-plot-shorelines-on-their-own.ipynb
    7-plot-shoreline-compared-to-hz.ipynb
    8-plot-how-shorelines-compare-to-zc17.ipynb
    9-apply-shoreline-to-specifc-questions.ipynb
    10-apply-to-rocky-worlds.ipynb
    11-make-zenodo-repository.ipynb'''.split():
    print(f'''
    ⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️
    ⌛️ running {f}
    ⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️⌛️
    ''')
    try:
        get_ipython().run_line_magic('run', f)
    except ShorelineStepAlreadyDoneError:
        pass
